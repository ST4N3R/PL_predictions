# %%
import pandas as pd

# %%
path = r"C:\Users\Stanisław\Desktop\Programowanie\GitHub\PL_predictions\epl_predictions\data\raw\results.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#        index  Wk  Day        Date   Time            Home Score  \
# 0          0   1  Sat  1995-08-19    NaN     Southampton   3–4
# 1          1   1  Sat  1995-08-19    NaN   Newcastle Utd   3–0
# 2          2   1  Sat  1995-08-19    NaN       Wimbledon   3–2
# 3          3   1  Sat  1995-08-19    NaN       Liverpool   1–0
# 4          4   1  Sat  1995-08-19    NaN        West Ham   1–2
# ...      ...  ..  ...         ...    ...             ...   ...
# 11015  11015  38  Sun  2024-05-19  16:00       Brentford   2–4
# 11016  11016  38  Sun  2024-05-19  16:00         Chelsea   2–1
# 11017  11017  38  Sun  2024-05-19  16:00  Crystal Palace   5–0
# 11018  11018  38  Sun  2024-05-19  16:00       Liverpool   2–0
# 11019  11019  38  Sun  2024-05-19  16:00         Burnley   1–2
#
#                   Away Attendance                    Venue         Referee  \
# 0      Nott'ham Forest     15,164                 The Dell    Gary Willard
# ...

# %%
df.iloc[-1, 4]
# Out:
# '16:00'

# %%
test = df["Match Report"]
test
# Out:
# 0        https://fbref.com/en/matches/1dc2482e/Southamp...
# 1        https://fbref.com/en/matches/1fe803e5/Newcastl...
# 2        https://fbref.com/en/matches/2e382ef4/Wimbledo...
# 3        https://fbref.com/en/matches/67aaa9bc/Liverpoo...
# 4        https://fbref.com/en/matches/70be787c/West-Ham...
#                                ...
# 11015    https://fbref.com/en/matches/546e1a3d/Brentfor...
# 11016    https://fbref.com/en/matches/7c034003/Chelsea-...
# 11017    https://fbref.com/en/matches/c975c7a6/Crystal-...
# 11018    https://fbref.com/en/matches/d4823ed5/Liverpoo...
# 11019    https://fbref.com/en/matches/dafb05fe/Burnley-...
# Name: Match Report, Length: 11020, dtype: object

# %%
for n in test:
    print(type(n))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
first_table_id = "stats_19538871_summary"
lol = "stats_b74092de_summary"
second_table_id = "stats_fd962109_summary"
