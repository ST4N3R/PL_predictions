# %%
import pandas as pd

# %%
path = r"C:\Users\Stanisław\Desktop\Programowanie\GitHub\PL_predictions\epl_predictions\data\raw\previous_tables.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#      Rk            Squad  MP   W   D   L  GF   GA  GD  Pts  Pts/MP Attendance  \
# 0     1   Manchester Utd  38  25   7   6  73   35  38   82    2.16     41,681
# 1     2    Newcastle Utd  38  24   6   8  66   37  29   78    2.05     36,505
# 2     3        Liverpool  38  20  11   7  70   34  36   71    1.87     39,553
# 3     4      Aston Villa  38  18   9  11  52   35  17   63    1.66     32,772
# 4     5          Arsenal  38  17  12   9  49   32  17   63    1.66     37,568
# ..   ..              ...  ..  ..  ..  ..  ..  ...  ..  ...     ...        ...
# 575  16        Brentford  38  10   9  19  56   65  -9   39    1.03     17,082
# 576  17  Nott'ham Forest  38   9   9  20  49   67 -18   32    0.84     29,386
# 577  18       Luton Town  38   6   8  24  52   85 -33   26    0.68     11,240
# 578  19          Burnley  38   5   9  24  41   78 -37   24    0.63     21,184
# 579  20    Sheffield Utd  38   3   7  28  35  104 -69   16    0.42     30,011
#
# ...
