# %%
import pandas as pd

# %%
path = r"C:\Users\Stanisław\Desktop\Programowanie\GitHub\PL_predictions\epl_predictions\data\raw\results.csv"

df = pd.read_csv(path)

# %%
df
# Out:
#        Wk  Day        Date   Time             Home Score             Away  \
# 0       1  Sat  1995-08-19    NaN      Southampton   3–4  Nott'ham Forest
# 1       1  Sat  1995-08-19    NaN    Newcastle Utd   3–0    Coventry City
# 2       1  Sat  1995-08-19    NaN        Wimbledon   3–2           Bolton
# 3       1  Sat  1995-08-19    NaN        Liverpool   1–0   Sheffield Weds
# 4       1  Sat  1995-08-19    NaN         West Ham   1–2     Leeds United
# ...    ..  ...         ...    ...              ...   ...              ...
# 11096   8  Sat  2024-10-19  17:30      Bournemouth   2–0          Arsenal
# 11097   8  Sun  2024-10-20  14:00           Wolves   1–2  Manchester City
# 11098   8  Sun  2024-10-20  16:30        Liverpool   2–1          Chelsea
# 11099   8  Mon  2024-10-21  20:00  Nott'ham Forest   1–0   Crystal Palace
# 11100   9  Fri  2024-10-25  20:00   Leicester City   1–3  Nott'ham Forest
#
#       Attendance               Venue         Referee  \
# 0         15,164            The Dell    Gary Willard
# 1         36,485     St. James' Park    Roger Dilkes
# 2          9,317       Selhurst Park    Keith Cooper
# 3         40,535             Anfield     Paul Durkin
# 4         22,901       Boleyn Ground     Keith Burge
# ...          ...                 ...             ...
# 11096     11,235    Vitality Stadium    Robert Jones
# 11097     31,319    Molineux Stadium  Chris Kavanagh
# 11098     60,277             Anfield     John Brooks
# 11099     29,443     The City Ground    Tim Robinson
# 11100     31,879  King Power Stadium    Craig Pawson
#
#                                             Match Report  Notes  xG_Home  \
# 0      https://fbref.com/en/matches/1dc2482e/Southamp...    NaN      NaN
# 1      https://fbref.com/en/matches/1fe803e5/Newcastl...    NaN      NaN
# 2      https://fbref.com/en/matches/2e382ef4/Wimbledo...    NaN      NaN
# 3      https://fbref.com/en/matches/67aaa9bc/Liverpoo...    NaN      NaN
# 4      https://fbref.com/en/matches/70be787c/West-Ham...    NaN      NaN
# ...                                                  ...    ...      ...
# 11096  https://fbref.com/en/matches/01e63a1f/Bournemo...    NaN      1.8
# 11097  https://fbref.com/en/matches/90b22cd5/Wolverha...    NaN      0.8
# 11098  https://fbref.com/en/matches/99b4737c/Liverpoo...    NaN      1.9
# 11099  https://fbref.com/en/matches/5ed3894e/Nottingh...    NaN      1.7
# 11100  https://fbref.com/en/matches/292d8bc4/Leiceste...    NaN      0.6
#
#        xG_Away     Season
# 0          NaN  1995-1996
# 1          NaN  1995-1996
# 2          NaN  1995-1996
# 3          NaN  1995-1996
# 4          NaN  1995-1996
# ...        ...        ...
# 11096      0.7  2024-2025
# 11097      1.6  2024-2025
# 11098      1.0  2024-2025
# 11099      1.0  2024-2025
# 11100      1.7  2024-2025
#
# [11101 rows x 15 columns]
